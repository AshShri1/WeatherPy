# %%
#Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import seaborn
#from citipy import citipy
import random
import csv
import requests
import time

# %%
api_key = "25bc90a1196e6f153eece0bc0b0fc9eb"

# %%
#Import CSV file, and read into DataFrame.

world_data = pd.read_csv("Resources/worldcities.csv")

#Preview the data.
world_data.head()
# Out:
#   Country              City   Latitude  Longitude
# 0      ad  andorra la vella  42.500000  1.5166667
# 1      ad           canillo  42.566667        1.6
# 2      ad            encamp  42.533333  1.5833333
# 3      ad        la massana  42.550000  1.5166667
# 4      ad      les escaldes  42.500000  1.5333333

# %%
# Randomly select 500 cities for weather data.

selected_cities = world_data.sample(n=500)

#Visualize the selected cities DataFrame.

selected_cities
# Out:
#       Country                   City   Latitude     Longitude
# 4440       ca            baie-comeau  49.216667        -68.15
# 38450      ru                svobody  44.025556     43.050278
# 33551      ro               merisani  44.966667     24.733333
# 38795      ru                usvyaty  55.745556     30.753333
# 18419      in              lasalgaon  20.150000     74.233333
# 43071      us                 dublin  32.540278   -82.9038889
# 25045      my             parit raja   1.868100      103.1124
# 37653      ru             pionerskiy  57.105955     63.750453
# 41997      ug                mubende   0.589167         31.36
# 23808      mx               frontera  18.425000    -92.833333
# 15702      hu                kiskore  47.500000          20.5
# 26108      no                  tomra  62.583333      6.933333
# 43864      us                 carver  41.883333   -70.7630556
# 14         af                  asmar  35.033328     71.358087
# 6946       co                  imues   1.060715    -77.500442
# 21526      jp                 kumano  33.903886    136.122138
# 26211      nz         hanmer springs -42.516667    172.816667
# 45375      us            hormigueros  18.141667   -67.1277778
# 5214       cf              bossangoa   6.483333         17.45
# 36371      ru                  kitoy  52.595278    103.855556
# 15867      hu                 ocseny  46.313697     18.757493
# 45823      us                 draper  40.524722  -111.8630556
# 25072      my                   sibu   2.300000    111.816667
# 20324      it      cinisello balsamo  45.550000      9.216667
# 7571       cr              chacarita   9.982886    -84.772319
# 37378      ru      novoye devyatkino  60.072692     30.478374
# 37913      ru           rozhdestveno  55.854436     37.049351
# 43398      us        western springs  41.809722   -87.9005556
# 42672      us               loveland  40.397778  -105.0744444
# 36176      ru               karachev  53.122918     34.985167
# ...       ...                    ...        ...           ...
# 7279       co                sampues   9.183611    -75.381667
# 13057      gb                 wishaw  55.766667     -3.916667
# 4966       ca          saint-prosper  46.200000    -70.483333
# 20786      it               pisticci  40.383333         16.55
# 3989       br  sao lourenco do oeste -26.400000    -52.766667
# 8642       de               bruchsal  49.128056      8.583611
# 30032      ph       santa cruz nuevo   9.535200      123.1054
# 26091      no               straumen  63.866667          11.3
# 7980       cz                 hronov  50.476002     16.182718
# 462        ao                 lumeje -11.550000     20.783333
# 44539      us              hammonton  39.636389   -74.8027778
# 10289      dz                tazmalt  36.387222     4.4016667
# 26137      no                 vestby  59.600000         10.75
# 40030      tc          cockburn town  21.466667   -71.1333333
# 13587      gr                 glossa  39.166667    23.6166667
# 17788      in               gulaothi  28.600000     77.783333
# 25840      no                 forset  61.200000         10.15
# 31056      pl                chelmno  53.350000     18.433333
# 15384      hu          balatonalmadi  47.035260     18.020763
# 12111      fr          tournefeuille  43.583905       1.34685
# 36929      ru        maloyaroslavets  55.014572     36.471853
# 25935      no                  leira  60.966667           9.3
# 31832      pt                tondela  40.516815     -8.080866
# 39755      sl                 kasiri   8.937222   -13.1244444
# 28474      ph                kitango   6.948333    124.441111
# 1855       bf                 boromo  11.750000    -2.9333333
# 24557      mx              tancitaro  19.333333   -102.366667
# 37554      ru                pashiya  58.432400       58.2562
# 35787      ru                dzhalka  43.318605     45.987872
# 32987      ro            dumbravesti  45.083333            26
#
# [500 rows x 4 columns]

# %%
#Counter

row_count = 0

# Create blank columns for the necessary fields.

selected_cities["Temperature"] = ""
selected_cities["Humidity"] = ""
selected_cities["Cloudiness"] = ""
selected_cities["Wind Speed"] = ""

# Loop through and get the weather data using the Open Weather API.

for index, row in selected_cities.iterrows():
    #Sleep to help with the call limit
    
    time.sleep(1)
    
    #Open weather url.
    
    url = "https://api.openweathermap.org/data/2.5/weather?"
    units = "Imperial"
    
    query_url = url + "lat="+ str(row["Latitude"]) + "&lon=" + str(row["Longitude"]) + "&appid=" + api_key + "&units=" + units
    #Print log to ensure the loop is working correctly.
    
    print("Now retieving city # " + str(row_count))
    print(query_url)
    row_count += 1
    
    #Run requests to grab the JSON at the requested URL
    
    city_weather = requests.get(query_url).json()
    
    
    #print(row["Latitude"],row["Longitude"])
#print(city_weather.keys())
    
    #Append the weather data to the appropriate columns.
    #Use try/except to skip any cities with errors.
    #selected_cities.append(requests.get(query_url + str(city_weather)).json())
    try:
        temperature = city_weather["main"]["temp"]
        humidity = city_weather["main"]["humidity"]
        cloudiness = city_weather["clouds"]["all"]
        wind_speed = city_weather["wind"]["speed"]
        
        selected_cities.set_value(index, "Temperature", temperature)
        selected_cities.set_value(index,"Humidity", humidity)
        selected_cities.set_value(index,"Cloudiness", cloudiness)
        selected_cities.set_value(index,"Wind Speed", wind_speed)
    except:
        print("Error with weather data, skipping.")
        #continue
selected_cities
# Out:
# Now retieving city # 0
# https://api.openweathermap.org/data/2.5/weather?lat=49.216667&lon=-68.15&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 1
# https://api.openweathermap.org/data/2.5/weather?lat=44.025556&lon=43.050278&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 2
# https://api.openweathermap.org/data/2.5/weather?lat=44.966667&lon=24.733333&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 3
# https://api.openweathermap.org/data/2.5/weather?lat=55.74555600000001&lon=30.753333&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 4
# https://api.openweathermap.org/data/2.5/weather?lat=20.15&lon=74.233333&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 5
# https://api.openweathermap.org/data/2.5/weather?lat=32.5402778&lon=-82.9038889&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 6
# https://api.openweathermap.org/data/2.5/weather?lat=1.8681&lon=103.1124&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 7
# https://api.openweathermap.org/data/2.5/weather?lat=57.105955&lon=63.750453&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 8
# https://api.openweathermap.org/data/2.5/weather?lat=0.5891666999999999&lon=31.36&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 9
# https://api.openweathermap.org/data/2.5/weather?lat=18.425&lon=-92.833333&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 10
# https://api.openweathermap.org/data/2.5/weather?lat=47.5&lon=20.5&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 11
# https://api.openweathermap.org/data/2.5/weather?lat=62.583332999999996&lon=6.933333&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 12
# https://api.openweathermap.org/data/2.5/weather?lat=41.8833333&lon=-70.7630556&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 13
# https://api.openweathermap.org/data/2.5/weather?lat=35.033328000000004&lon=71.358087&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 14
# https://api.openweathermap.org/data/2.5/weather?lat=1.060715&lon=-77.500442&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 15
# https://api.openweathermap.org/data/2.5/weather?lat=33.903886&lon=136.122138&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 16
# https://api.openweathermap.org/data/2.5/weather?lat=-42.516667&lon=172.816667&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 17
# https://api.openweathermap.org/data/2.5/weather?lat=18.1416667&lon=-67.1277778&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 18
# https://api.openweathermap.org/data/2.5/weather?lat=6.4833333&lon=17.45&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 19
# https://api.openweathermap.org/data/2.5/weather?lat=52.595278&lon=103.855556&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 20
# https://api.openweathermap.org/data/2.5/weather?lat=46.313697&lon=18.757493&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# Now retieving city # 21
# https://api.openweathermap.org/data/2.5/weather?lat=40.5247222&lon=-111.8630556&appid=25bc90a1196e6f153eece0bc0b0fc9eb&units=Imperial
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-ec3bd63ba73b> in <module>()
#      31     #Run requests to grab the JSON at the requested URL
#      32
# ---> 33     city_weather = requests.get(query_url).json()
#      34
#      35
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     348         # Trigger any extra validation we need to do.
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#     352             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     833         # Force connect early to allow us to validate the connection.
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#     837         if not conn.is_verified:
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     279     def connect(self):
#     280         # Add certificate verification
# --> 281         conn = self._new_conn()
#     282
#     283         hostname = self.host
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     136         try:
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#     140         except SocketTimeout as e:
#
# /Users/ashishshrivastava/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      86             if source_address:
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#      90
#
# KeyboardInterrupt:

# %%
selected_cities.to_csv("WorldWeatherData.csv", index=False)

# %%
plt.scatter(selected_cities["Latitude"],selected_cities["Temperature"], alpha = 0.5)

plt.title("Temperature (F) vs. Latitude Date of Analysis")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("Temperature.png")
plt.show()

# %%
plt.scatter(selected_cities["Latitude"],selected_cities["Humidity"], alpha = 0.75)

plt.title("Latitude vs. Humidity Date of Analysis")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("Humidity.png")
plt.show()

# %%
plt.scatter(selected_cities["Latitude"],selected_cities["Humidity"], alpha = 0.75)

plt.title("Latitude vs. Humidity Date of Analysis")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("Humidity.png")
plt.show()

# %%
plt.scatter(selected_cities["Latitude"],selected_cities["Wind Speed"], alpha= 0.75)
plt.title("Latitude vs Wind Speed Date of Analysis")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("Wind Speed.png")
plt.show()

# %%
plt.scatter(selected_cities["Longitude"],selected_cities["Latitude"])
plt.title("Longitude vs Latitude")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.savefig("LongitudeLatitude.png")
plt.show()
